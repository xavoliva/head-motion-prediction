# %%
# %load_ext autoreload
# %autoreload 2

# %%
import math
import os
import time
from os.path import isfile, join

import numpy as np
import tensorflow as tf
from scipy.ndimage import gaussian_filter, zoom
from scipy.special import logsumexp

import cv2
import utils.equirec_2_perspec as E2P
from utils.read_write_h5 import store_many_hdf5

# equ = E2P.Equirectangular('src/image.jpg')    # Load equirectangular image

# FOV unit is degree
# theta is z-axis angle(right direction is positive, left direction is negative)
# phi is y-axis angle(up direction positive, down direction negative)
# height and width is output image dimension

DIR_PATH = os.getcwd()

# %%
def equirect_to_spherical(x_eq, y_eq, width_px, height_px):
    """
    Convert equirectangular coordinates to spherical angles in degree for use in
    equirec_2_perspec
    """
    theta_rad = (x_eq * 2 * math.pi) / width_px
    phi_rad = (-y_eq * math.pi) / height_px

    theta_deg = theta_rad * (180 / math.pi) - 180
    phi_deg = phi_rad * (180 / math.pi) + 90
    return theta_deg, phi_deg

# Validity check
equirect_to_spherical(np.array([1920, 1920]), np.array([960, 960]), 3840, 1920)
# Out:
# (array([-2.84217094e-14, -2.84217094e-14]),
#  array([1.42108547e-14, 1.42108547e-14]))

# %%
tf.reset_default_graph()

check_point = os.path.join('deep_gaze', 'DeepGazeII.ckpt')  # DeepGaze II
#check_point = 'ICF.ckpt'  # ICF
new_saver = tf.train.import_meta_graph('{}.meta'.format(check_point))

input_tensor = tf.get_collection('input_tensor')[0]
centerbias_tensor = tf.get_collection('centerbias_tensor')[0]
log_density = tf.get_collection('log_density')[0]
log_density_wo_centerbias = tf.get_collection('log_density_wo_centerbias')[0]
# Out:
# WARNING:tensorflow:The saved meta_graph is possibly from an older release:
# 'model_variables' collection should be of type 'byte_list', but instead is of type 'node_list'.

# %%
TRAIN_DIR = join(DIR_PATH, "preprocessed_train")
TEST_DIR = join(DIR_PATH, "preprocessed_test")
FILES = sorted([f for f in os.listdir(TEST_DIR) if isfile(join(TEST_DIR, f))])
for i, file in enumerate(FILES):
    print(i, file)

#FILES = ['002_08_madagascar_cuts.npy']
# Out:
# 0 042_01_art_gallery_static.npy
# 1 042_02_theatre_scene_static.npy
# 2 042_03_lions_static_cuts.npy
# 3 042_04_copenhagen_harbour_static_cuts.npy
# 4 042_05_florida_yacht_motion.npy
# 5 042_07_factory_robots_static.npy
# 6 042_08_madagascar_cuts.npy
# 7 042_11_lohdi_garden_india_cuts.npy
# 8 042_12_gym_workout_static.npy
# 9 042_13_times_square_static.npy
# 10 042_16_interview_static.npy
# 11 042_17_weather_forecast_static.npy
# 12 042_18_bomb_trapped_static.npy
# 13 042_20_car_fix_static.npy
# 14 042_21_operation_room_static.npy
# 15 042_23_dog_food_factory_motion.npy
# 16 043_01_art_gallery_static.npy
# 17 043_02_theatre_scene_static.npy
# 18 043_03_lions_static_cuts.npy
# 19 043_04_copenhagen_harbour_static_cuts.npy
# 20 043_07_factory_robots_static.npy
# 21 043_08_madagascar_cuts.npy
# 22 043_09_elephants_static.npy
# 23 043_11_lohdi_garden_india_cuts.npy
# 24 043_13_times_square_static.npy
# 25 043_16_interview_static.npy
# 26 043_17_weather_forecast_static.npy
# 27 043_18_bomb_trapped_static.npy
# 28 043_20_car_fix_static.npy
# 29 043_21_operation_room_static.npy
# 30 043_23_dog_food_factory_motion.npy
# 31 044_01_art_gallery_static.npy
# 32 044_02_theatre_scene_static.npy
# 33 044_03_lions_static_cuts.npy
# 34 044_04_copenhagen_harbour_static_cuts.npy
# 35 044_05_florida_yacht_motion.npy
# 36 044_07_factory_robots_static.npy
# 37 044_08_madagascar_cuts.npy
# 38 044_09_elephants_static.npy
# 39 044_11_lohdi_garden_india_cuts.npy
# 40 044_12_gym_workout_static.npy
# 41 044_13_times_square_static.npy
# 42 044_14_new_orleans_drive_motion.npy
# 43 044_16_interview_static.npy
# 44 044_17_weather_forecast_static.npy
# 45 044_18_bomb_trapped_static.npy
# 46 044_20_car_fix_static.npy
# 47 044_21_operation_room_static.npy
# 48 044_23_dog_food_factory_motion.npy
# 49 045_01_art_gallery_static.npy
# 50 045_02_theatre_scene_static.npy
# 51 045_03_lions_static_cuts.npy
# 52 045_04_copenhagen_harbour_static_cuts.npy
# 53 045_05_florida_yacht_motion.npy
# 54 045_07_factory_robots_static.npy
# 55 045_08_madagascar_cuts.npy
# 56 045_09_elephants_static.npy
# 57 045_11_lohdi_garden_india_cuts.npy
# 58 045_12_gym_workout_static.npy
# 59 045_13_times_square_static.npy
# 60 045_14_new_orleans_drive_motion.npy
# 61 045_16_interview_static.npy
# 62 045_17_weather_forecast_static.npy
# 63 045_18_bomb_trapped_static.npy
# 64 045_20_car_fix_static.npy
# 65 045_21_operation_room_static.npy
# 66 045_23_dog_food_factory_motion.npy
# 67 046_01_art_gallery_static.npy
# 68 046_02_theatre_scene_static.npy
# 69 046_03_lions_static_cuts.npy
# 70 046_04_copenhagen_harbour_static_cuts.npy
# 71 046_05_florida_yacht_motion.npy
# 72 046_07_factory_robots_static.npy
# 73 046_09_elephants_static.npy
# 74 046_11_lohdi_garden_india_cuts.npy
# 75 046_12_gym_workout_static.npy
# 76 046_13_times_square_static.npy
# 77 046_14_new_orleans_drive_motion.npy
# 78 046_16_interview_static.npy
# 79 046_17_weather_forecast_static.npy
# 80 046_18_bomb_trapped_static.npy
# 81 046_20_car_fix_static.npy
# 82 046_21_operation_room_static.npy
# 83 046_23_dog_food_factory_motion.npy
# 84 047_01_art_gallery_static.npy
# 85 047_02_theatre_scene_static.npy
# 86 047_03_lions_static_cuts.npy
# 87 047_04_copenhagen_harbour_static_cuts.npy
# 88 047_05_florida_yacht_motion.npy
# 89 047_07_factory_robots_static.npy
# 90 047_08_madagascar_cuts.npy
# 91 047_09_elephants_static.npy
# 92 047_11_lohdi_garden_india_cuts.npy
# 93 047_12_gym_workout_static.npy
# 94 047_13_times_square_static.npy
# 95 047_14_new_orleans_drive_motion.npy
# 96 047_16_interview_static.npy
# 97 047_17_weather_forecast_static.npy
# 98 047_18_bomb_trapped_static.npy
# 99 047_20_car_fix_static.npy
# 100 047_21_operation_room_static.npy
# 101 047_23_dog_food_factory_motion.npy
# 102 048_01_art_gallery_static.npy
# 103 048_02_theatre_scene_static.npy
# 104 048_03_lions_static_cuts.npy
# 105 048_04_copenhagen_harbour_static_cuts.npy
# 106 048_05_florida_yacht_motion.npy
# 107 048_07_factory_robots_static.npy
# 108 048_08_madagascar_cuts.npy
# 109 048_09_elephants_static.npy
# 110 048_11_lohdi_garden_india_cuts.npy
# 111 048_12_gym_workout_static.npy
# 112 048_13_times_square_static.npy
# 113 048_14_new_orleans_drive_motion.npy
# 114 048_16_interview_static.npy
# 115 048_17_weather_forecast_static.npy
# 116 048_18_bomb_trapped_static.npy
# 117 048_20_car_fix_static.npy
# 118 048_21_operation_room_static.npy
# 119 048_23_dog_food_factory_motion.npy
# 120 049_01_art_gallery_static.npy
# 121 049_02_theatre_scene_static.npy
# 122 049_03_lions_static_cuts.npy
# 123 049_04_copenhagen_harbour_static_cuts.npy
# 124 049_05_florida_yacht_motion.npy
# 125 049_07_factory_robots_static.npy
# 126 049_08_madagascar_cuts.npy
# 127 049_09_elephants_static.npy
# 128 049_11_lohdi_garden_india_cuts.npy
# 129 049_12_gym_workout_static.npy
# 130 049_13_times_square_static.npy
# 131 049_14_new_orleans_drive_motion.npy
# 132 049_17_weather_forecast_static.npy
# 133 049_18_bomb_trapped_static.npy
# 134 049_20_car_fix_static.npy
# 135 049_21_operation_room_static.npy
# 136 049_23_dog_food_factory_motion.npy
# 137 050_01_art_gallery_static.npy
# 138 050_02_theatre_scene_static.npy
# 139 050_03_lions_static_cuts.npy
# 140 050_04_copenhagen_harbour_static_cuts.npy
# 141 050_05_florida_yacht_motion.npy
# 142 050_07_factory_robots_static.npy
# 143 050_08_madagascar_cuts.npy
# 144 050_09_elephants_static.npy
# 145 050_11_lohdi_garden_india_cuts.npy
# 146 050_12_gym_workout_static.npy
# 147 050_13_times_square_static.npy
# 148 050_14_new_orleans_drive_motion.npy
# 149 050_16_interview_static.npy
# 150 050_17_weather_forecast_static.npy
# 151 050_18_bomb_trapped_static.npy
# 152 050_20_car_fix_static.npy
# 153 050_21_operation_room_static.npy
# 154 050_23_dog_food_factory_motion.npy

# %%
FOVE_FOV = 100 # 100 degrees
FOVE_WIDTH_PX = 512 # 2560/5
FOVE_HEIGHT_PX = 288 # 1440/5

FINAL_WIDTH_PX = 128 # 2560/20
FINAL_HEIGHT_PX = 72 # 1440/20

# load precomputed log density over a 1024x1024 image
centerbias_template = np.load(os.path.join('deep_gaze', 'centerbias.npy'))
# rescale to match image size
centerbias = zoom(centerbias_template, (FOVE_HEIGHT_PX/1024, FOVE_WIDTH_PX/1024),
                  order=0, mode='nearest')
# renormalize log density
centerbias -= logsumexp(centerbias)

centerbias_data = centerbias[np.newaxis, :, :, np.newaxis]  # BHWC, 1 channel (log density)

# %%
def resize_images(images, height_output, width_output):
    """
    Returns two arrays:
        resized_images is an array of resized images (N, height_output, width_output, CHANNELS)
    """

    resized_images = None

    for full_size_image in images:
        # Read and resize image
        if resized_images is None:
            resized_images = np.expand_dims(cv2.resize(full_size_image,
                                                       (width_output, height_output),
                                                       interpolation=cv2.INTER_CUBIC), axis=0)
        else:
            resized_images = np.vstack((
                resized_images,
                np.expand_dims(cv2.resize(full_size_image, (width_output, height_output),
                                          interpolation=cv2.INTER_CUBIC), axis=0)
            ))

    # if gray image
    if resized_images.ndim == 3:
        resized_images = np.expand_dims(resized_images, axis=3)
    return resized_images

# %%
#COLUMNS = ['x', 'y', 'x_head', 'y_head', 'angle_deg_head', 'quaternion_hp_w',
#        'quaternion_hp_x', 'quaternion_hp_y', 'quaternion_hp_z', 'frameId']

#session_conf = tf.ConfigProto()
#session_conf.gpu_options.allow_growth = True
with tf.Session() as sess:
    new_saver.restore(sess, check_point)
    start_index = 0
    VIDEO_WIDTH = 3840
    dir_path_fov = join(DIR_PATH, "fov_images_test_h5_new", "original")
    dir_path_fov_saliency = join(DIR_PATH, "fov_images_test_h5_new", "saliency")
    for file in FILES[start_index:]:
        start_time_video = time.time()
        video_data = np.load(join(DIR_PATH, "preprocessed_test", file))
        video_name_user = file[:-4]
        video_name = file[4:-4]
        video_path = join(DIR_PATH, 'datasetTUM', 'videos', video_name + ".mp4")
        print(video_name_user)
        video_height = video_data[0, 1] * 2

        original_images = None
        sal_images = None

        vidcap = cv2.VideoCapture(video_path)

        success, image_frame = vidcap.read()
        frame_id = 0

        start_time_video = time.time()
        for i, row in enumerate(video_data):
            frame_id_row = int(row[9])
            if frame_id_row > frame_id:
                # Compute mean of frame data
                frame_data = np.mean(video_data[video_data[:, 9].astype(int) == frame_id], axis=0)
                #print(frame_data.shape)
                theta, phi = equirect_to_spherical(frame_data[2], frame_data[3],
                                                        VIDEO_WIDTH, video_height)
                success, image_frame = vidcap.read()
                #print(success, int(frame_id_row), frame_id)
                if success:
                    # Create FoV image
                    equ = E2P.Equirectangular(image_frame)
                    #print(row[0], row[1], x_head_eq, y_head_eq, theta, phi)
                    img_fov = equ.get_perspective(FOVE_FOV, theta, phi,
                                                 FOVE_HEIGHT_PX, FOVE_WIDTH_PX)
                    img_fov = np.expand_dims(img_fov, axis=0)
                    #print("img_fov", img_fov.shape)
                    if original_images is not None:
                        original_images = np.vstack((original_images, img_fov))
                    else:
                        original_images = img_fov
                    #print(frame_id)
                    frame_id += 1
                else:
                    print("No more frames")
                    break


        #original_images = original_images / np.amax(original_images)
        print("original_images", original_images.shape)
        tiny_images = resize_images(original_images, FINAL_HEIGHT_PX, FINAL_WIDTH_PX)
        print("tiny_images", tiny_images.shape)
        store_many_hdf5(tiny_images, dir_path_fov, video_name_user)
        # Apply DeepGaze II to FoV images
        batch_size = 2**5
        print("Starting generation of saliency maps")
        for index in range(0, len(original_images), batch_size):
            batch_original_images = original_images[index:min(index+batch_size,
                                                              len(original_images))]
            batch_log_density_prediction = sess.run(log_density, {
                input_tensor: batch_original_images,
                centerbias_tensor: centerbias_data,
            })
            batch_saliency_images = np.exp(batch_log_density_prediction)
            for i, sal_image in enumerate(batch_saliency_images):
                sal_image = gaussian_filter(sal_image, sigma=5)
                sal_image = sal_image / np.amax(sal_image) * 255
                batch_saliency_images[i] = sal_image

            if sal_images is not None:
                sal_images = np.vstack((sal_images, batch_saliency_images))
            else:
                sal_images = batch_saliency_images

        print("sal_images", sal_images.shape)
        tiny_sal_images = resize_images(sal_images, FINAL_HEIGHT_PX, FINAL_WIDTH_PX)
        print("tiny_sal_images", tiny_sal_images.shape)
        store_many_hdf5(tiny_sal_images, dir_path_fov_saliency, video_name_user)

        print("Time per video: " + str(time.time() - start_time_video) + " seconds,",
              str((time.time() - start_time_video)/60) + " minutes.")
# Out:
# INFO:tensorflow:Restoring parameters from deep_gaze/DeepGazeII.ckpt
# 042_01_art_gallery_static
# original_images (1836, 288, 512, 3)
# tiny_images (1836, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1836, 288, 512, 1)
# tiny_sal_images (1836, 72, 128, 1)
# Time per video: 462.74562644958496 seconds, 7.712427194913229 minutes.
# 042_02_theatre_scene_static
# original_images (1852, 288, 512, 3)
# tiny_images (1852, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1852, 288, 512, 1)
# tiny_sal_images (1852, 72, 128, 1)
# Time per video: 452.5006220340729 seconds, 7.5416771133740745 minutes.
# 042_03_lions_static_cuts
# No more frames
# original_images (1860, 288, 512, 3)
# tiny_images (1860, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1860, 288, 512, 1)
# tiny_sal_images (1860, 72, 128, 1)
# Time per video: 457.5896077156067 seconds, 7.626493545373281 minutes.
# 042_04_copenhagen_harbour_static_cuts
# No more frames
# original_images (1860, 288, 512, 3)
# tiny_images (1860, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1860, 288, 512, 1)
# tiny_sal_images (1860, 72, 128, 1)
# Time per video: 455.7948281764984 seconds, 7.596580553054809 minutes.
# 042_05_florida_yacht_motion
# original_images (1348, 288, 512, 3)
# tiny_images (1348, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1348, 288, 512, 1)
# tiny_sal_images (1348, 72, 128, 1)
# Time per video: 268.3912031650543 seconds, 4.473186802864075 minutes.
# 042_07_factory_robots_static
# original_images (1788, 288, 512, 3)
# tiny_images (1788, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1788, 288, 512, 1)
# tiny_sal_images (1788, 72, 128, 1)
# Time per video: 424.30048656463623 seconds, 7.07167485555013 minutes.
# 042_08_madagascar_cuts
# original_images (1582, 288, 512, 3)
# tiny_images (1582, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1582, 288, 512, 1)
# tiny_sal_images (1582, 72, 128, 1)
# Time per video: 346.334050655365 seconds, 5.772234257062276 minutes.
# 042_11_lohdi_garden_india_cuts
# No more frames
# original_images (1860, 288, 512, 3)
# tiny_images (1860, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1860, 288, 512, 1)
# tiny_sal_images (1860, 72, 128, 1)
# Time per video: 457.88616824150085 seconds, 7.63143622080485 minutes.
# 042_12_gym_workout_static
# original_images (1845, 288, 512, 3)
# tiny_images (1845, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1845, 288, 512, 1)
# tiny_sal_images (1845, 72, 128, 1)
# Time per video: 454.08749079704285 seconds, 7.568124922116597 minutes.
# 042_13_times_square_static
# original_images (1820, 288, 512, 3)
# tiny_images (1820, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1820, 288, 512, 1)
# tiny_sal_images (1820, 72, 128, 1)
# Time per video: 441.52763533592224 seconds, 7.3587940017382305 minutes.
# 042_16_interview_static
# /usr/local/lib/python3.5/dist-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /usr/local/lib/python3.5/dist-packages/numpy/core/_methods.py:78: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)
# /media/demo/DATA/saliency-exploitation/sw/utils/equirec_2_perspec.py:64: RuntimeWarning: invalid value encountered in greater
#   idx1 = xyz[:, 0] > 0
# /media/demo/DATA/saliency-exploitation/sw/utils/equirec_2_perspec.py:65: RuntimeWarning: invalid value encountered in greater
#   idx2 = xyz[:, 1] > 0
# original_images (1829, 288, 512, 3)
# tiny_images (1829, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1829, 288, 512, 1)
# tiny_sal_images (1829, 72, 128, 1)
# Time per video: 444.7702827453613 seconds, 7.412838125228882 minutes.
# 042_17_weather_forecast_static
# original_images (1851, 288, 512, 3)
# tiny_images (1851, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1851, 288, 512, 1)
# tiny_sal_images (1851, 72, 128, 1)
# Time per video: 457.07122683525085 seconds, 7.617853856086731 minutes.
# 042_18_bomb_trapped_static
# original_images (1801, 288, 512, 3)
# tiny_images (1801, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1801, 288, 512, 1)
# tiny_sal_images (1801, 72, 128, 1)
# Time per video: 434.8360290527344 seconds, 7.247267230351766 minutes.
# 042_20_car_fix_static
# original_images (1918, 288, 512, 3)
# tiny_images (1918, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1918, 288, 512, 1)
# tiny_sal_images (1918, 72, 128, 1)
# Time per video: 481.69014739990234 seconds, 8.028169198830922 minutes.
# 042_21_operation_room_static
# No more frames
# original_images (1922, 288, 512, 3)
# tiny_images (1922, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1922, 288, 512, 1)
# tiny_sal_images (1922, 72, 128, 1)
# Time per video: 480.99701023101807 seconds, 8.016616920630137 minutes.
# 042_23_dog_food_factory_motion
# No more frames
# original_images (1801, 288, 512, 3)
# tiny_images (1801, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1801, 288, 512, 1)
# tiny_sal_images (1801, 72, 128, 1)
# Time per video: 433.3786220550537 seconds, 7.222977113723755 minutes.
# 043_01_art_gallery_static
# original_images (1852, 288, 512, 3)
# tiny_images (1852, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1852, 288, 512, 1)
# tiny_sal_images (1852, 72, 128, 1)
# Time per video: 455.6614558696747 seconds, 7.594357681274414 minutes.
# 043_02_theatre_scene_static
# original_images (1854, 288, 512, 3)
# tiny_images (1854, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1854, 288, 512, 1)
# tiny_sal_images (1854, 72, 128, 1)
# Time per video: 451.65128469467163 seconds, 7.5275214870770775 minutes.
# 043_03_lions_static_cuts
# original_images (1855, 288, 512, 3)
# tiny_images (1855, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1855, 288, 512, 1)
# tiny_sal_images (1855, 72, 128, 1)
# Time per video: 455.1217088699341 seconds, 7.585361893971761 minutes.
# 043_04_copenhagen_harbour_static_cuts
# original_images (1855, 288, 512, 3)
# tiny_images (1855, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1855, 288, 512, 1)
# tiny_sal_images (1855, 72, 128, 1)
# Time per video: 456.5938911437988 seconds, 7.609898261229197 minutes.
# 043_07_factory_robots_static
# original_images (1793, 288, 512, 3)
# tiny_images (1793, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1793, 288, 512, 1)
# tiny_sal_images (1793, 72, 128, 1)
# Time per video: 428.1339159011841 seconds, 7.135565348466238 minutes.
# 043_08_madagascar_cuts
# original_images (1581, 288, 512, 3)
# tiny_images (1581, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1581, 288, 512, 1)
# tiny_sal_images (1581, 72, 128, 1)
# Time per video: 347.0972480773926 seconds, 5.784954218069712 minutes.
# 043_09_elephants_static
# original_images (1852, 288, 512, 3)
# tiny_images (1852, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1852, 288, 512, 1)
# tiny_sal_images (1852, 72, 128, 1)
# Time per video: 450.0495762825012 seconds, 7.50082635084788 minutes.
# 043_11_lohdi_garden_india_cuts
# original_images (1860, 288, 512, 3)
# tiny_images (1860, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1860, 288, 512, 1)
# tiny_sal_images (1860, 72, 128, 1)
# Time per video: 459.3736824989319 seconds, 7.656228125095367 minutes.
# 043_13_times_square_static
# original_images (1855, 288, 512, 3)
# tiny_images (1855, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1855, 288, 512, 1)
# tiny_sal_images (1855, 72, 128, 1)
# Time per video: 455.54495000839233 seconds, 7.592415916919708 minutes.
# 043_16_interview_static
# original_images (1858, 288, 512, 3)
# tiny_images (1858, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1858, 288, 512, 1)
# tiny_sal_images (1858, 72, 128, 1)
# Time per video: 454.1836898326874 seconds, 7.569728247324625 minutes.
# 043_17_weather_forecast_static
# original_images (1852, 288, 512, 3)
# tiny_images (1852, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1852, 288, 512, 1)
# tiny_sal_images (1852, 72, 128, 1)
# Time per video: 454.4694855213165 seconds, 7.574491500854492 minutes.
# 043_18_bomb_trapped_static
# original_images (1794, 288, 512, 3)
# tiny_images (1794, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1794, 288, 512, 1)
# tiny_sal_images (1794, 72, 128, 1)
# Time per video: 431.5378143787384 seconds, 7.192296985785166 minutes.
# 043_20_car_fix_static
# original_images (1912, 288, 512, 3)
# tiny_images (1912, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1912, 288, 512, 1)
# tiny_sal_images (1912, 72, 128, 1)
# Time per video: 478.4946720600128 seconds, 7.974911288420359 minutes.
# 043_21_operation_room_static
# original_images (1911, 288, 512, 3)
# tiny_images (1911, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1911, 288, 512, 1)
# tiny_sal_images (1911, 72, 128, 1)
# Time per video: 476.4783515930176 seconds, 7.941305947303772 minutes.
# 043_23_dog_food_factory_motion
# No more frames
# original_images (1801, 288, 512, 3)
# tiny_images (1801, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1801, 288, 512, 1)
# tiny_sal_images (1801, 72, 128, 1)
# Time per video: 432.2516508102417 seconds, 7.204194255669912 minutes.
# 044_01_art_gallery_static
# original_images (1858, 288, 512, 3)
# tiny_images (1858, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1858, 288, 512, 1)
# tiny_sal_images (1858, 72, 128, 1)
# Time per video: 458.88474798202515 seconds, 7.648079220453898 minutes.
# 044_02_theatre_scene_static
# original_images (1854, 288, 512, 3)
# tiny_images (1854, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1854, 288, 512, 1)
# tiny_sal_images (1854, 72, 128, 1)
# Time per video: 453.0239808559418 seconds, 7.550399772326151 minutes.
# 044_03_lions_static_cuts
# original_images (1854, 288, 512, 3)
# tiny_images (1854, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1854, 288, 512, 1)
# tiny_sal_images (1854, 72, 128, 1)
# Time per video: 454.5875630378723 seconds, 7.576459467411041 minutes.
# 044_04_copenhagen_harbour_static_cuts
# original_images (1851, 288, 512, 3)
# tiny_images (1851, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1851, 288, 512, 1)
# tiny_sal_images (1851, 72, 128, 1)
# Time per video: 455.06248712539673 seconds, 7.5843748609224955 minutes.
# 044_05_florida_yacht_motion
# original_images (1347, 288, 512, 3)
# tiny_images (1347, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1347, 288, 512, 1)
# tiny_sal_images (1347, 72, 128, 1)
# Time per video: 268.859281539917 seconds, 4.4809881011645 minutes.
# 044_07_factory_robots_static
# original_images (1797, 288, 512, 3)
# tiny_images (1797, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1797, 288, 512, 1)
# tiny_sal_images (1797, 72, 128, 1)
# Time per video: 428.6593382358551 seconds, 7.144322387377421 minutes.
# 044_08_madagascar_cuts
# original_images (1586, 288, 512, 3)
# tiny_images (1586, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1586, 288, 512, 1)
# tiny_sal_images (1586, 72, 128, 1)
# Time per video: 349.1308078765869 seconds, 5.818846881389618 minutes.
# 044_09_elephants_static
# original_images (1854, 288, 512, 3)
# tiny_images (1854, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1854, 288, 512, 1)
# tiny_sal_images (1854, 72, 128, 1)
# Time per video: 452.5774736404419 seconds, 7.542957973480225 minutes.
# 044_11_lohdi_garden_india_cuts
# original_images (1843, 288, 512, 3)
# tiny_images (1843, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1843, 288, 512, 1)
# tiny_sal_images (1843, 72, 128, 1)
# Time per video: 452.2273201942444 seconds, 7.537122082710266 minutes.
# 044_12_gym_workout_static
# original_images (1849, 288, 512, 3)
# tiny_images (1849, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1849, 288, 512, 1)
# tiny_sal_images (1849, 72, 128, 1)
# Time per video: 452.77804613113403 seconds, 7.546300848325093 minutes.
# 044_13_times_square_static
# No more frames
# original_images (1860, 288, 512, 3)
# tiny_images (1860, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1860, 288, 512, 1)
# tiny_sal_images (1860, 72, 128, 1)
# Time per video: 461.08411288261414 seconds, 7.6847352941830955 minutes.
# 044_14_new_orleans_drive_motion
# original_images (1796, 288, 512, 3)
# tiny_images (1796, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1796, 288, 512, 1)
# tiny_sal_images (1796, 72, 128, 1)
# Time per video: 431.5882031917572 seconds, 7.19313679933548 minutes.
# 044_16_interview_static
# original_images (1850, 288, 512, 3)
# tiny_images (1850, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1850, 288, 512, 1)
# tiny_sal_images (1850, 72, 128, 1)
# Time per video: 457.3641984462738 seconds, 7.622736978530884 minutes.
# 044_17_weather_forecast_static
# No more frames
# original_images (1860, 288, 512, 3)
# tiny_images (1860, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1860, 288, 512, 1)
# tiny_sal_images (1860, 72, 128, 1)
# Time per video: 457.449565410614 seconds, 7.62415949900945 minutes.
# 044_18_bomb_trapped_static
# original_images (1795, 288, 512, 3)
# tiny_images (1795, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1795, 288, 512, 1)
# tiny_sal_images (1795, 72, 128, 1)
# Time per video: 435.20060563087463 seconds, 7.253343518575033 minutes.
# 044_20_car_fix_static
# original_images (1913, 288, 512, 3)
# tiny_images (1913, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1913, 288, 512, 1)
# tiny_sal_images (1913, 72, 128, 1)
# Time per video: 480.9543879032135 seconds, 8.015906564394633 minutes.
# 044_21_operation_room_static
# original_images (1912, 288, 512, 3)
# tiny_images (1912, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1912, 288, 512, 1)
# tiny_sal_images (1912, 72, 128, 1)
# Time per video: 478.5937759876251 seconds, 7.976563008626302 minutes.
# 044_23_dog_food_factory_motion
# original_images (1798, 288, 512, 3)
# tiny_images (1798, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1798, 288, 512, 1)
# tiny_sal_images (1798, 72, 128, 1)
# Time per video: 435.9589214324951 seconds, 7.265982099374136 minutes.
# 045_01_art_gallery_static
# original_images (1840, 288, 512, 3)
# tiny_images (1840, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1840, 288, 512, 1)
# tiny_sal_images (1840, 72, 128, 1)
# Time per video: 452.3760406970978 seconds, 7.539600757757823 minutes.
# 045_02_theatre_scene_static
# No more frames
# original_images (1860, 288, 512, 3)
# tiny_images (1860, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1860, 288, 512, 1)
# tiny_sal_images (1860, 72, 128, 1)
# Time per video: 457.4370262622833 seconds, 7.623950513203939 minutes.
# 045_03_lions_static_cuts
# original_images (1846, 288, 512, 3)
# tiny_images (1846, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1846, 288, 512, 1)
# tiny_sal_images (1846, 72, 128, 1)
# Time per video: 455.6231207847595 seconds, 7.593718759218851 minutes.
# 045_04_copenhagen_harbour_static_cuts
# original_images (1846, 288, 512, 3)
# tiny_images (1846, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1846, 288, 512, 1)
# tiny_sal_images (1846, 72, 128, 1)
# Time per video: 454.4614899158478 seconds, 7.5743582367897035 minutes.
# 045_05_florida_yacht_motion
# original_images (1334, 288, 512, 3)
# tiny_images (1334, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1334, 288, 512, 1)
# tiny_sal_images (1334, 72, 128, 1)
# Time per video: 263.2017869949341 seconds, 4.386696533362071 minutes.
# 045_07_factory_robots_static
# original_images (1792, 288, 512, 3)
# tiny_images (1792, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1792, 288, 512, 1)
# tiny_sal_images (1792, 72, 128, 1)
# Time per video: 429.52671790122986 seconds, 7.158778703212738 minutes.
# 045_08_madagascar_cuts
# original_images (1573, 288, 512, 3)
# tiny_images (1573, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1573, 288, 512, 1)
# tiny_sal_images (1573, 72, 128, 1)
# Time per video: 346.22276401519775 seconds, 5.770379483699799 minutes.
# 045_09_elephants_static
# original_images (1844, 288, 512, 3)
# tiny_images (1844, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1844, 288, 512, 1)
# tiny_sal_images (1844, 72, 128, 1)
# Time per video: 452.12038016319275 seconds, 7.535339748859405 minutes.
# 045_11_lohdi_garden_india_cuts
# original_images (1845, 288, 512, 3)
# tiny_images (1845, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1845, 288, 512, 1)
# tiny_sal_images (1845, 72, 128, 1)
# Time per video: 455.8195552825928 seconds, 7.596992675463358 minutes.
# 045_12_gym_workout_static
# original_images (1839, 288, 512, 3)
# tiny_images (1839, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1839, 288, 512, 1)
# tiny_sal_images (1839, 72, 128, 1)
# Time per video: 448.9865868091583 seconds, 7.483109859625499 minutes.
# 045_13_times_square_static
# original_images (1836, 288, 512, 3)
# tiny_images (1836, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1836, 288, 512, 1)
# tiny_sal_images (1836, 72, 128, 1)
# Time per video: 452.29331517219543 seconds, 7.538222002983093 minutes.
# 045_14_new_orleans_drive_motion
# original_images (1786, 288, 512, 3)
# tiny_images (1786, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1786, 288, 512, 1)
# tiny_sal_images (1786, 72, 128, 1)
# Time per video: 429.4271574020386 seconds, 7.157119365533193 minutes.
# 045_16_interview_static
# original_images (1841, 288, 512, 3)
# tiny_images (1841, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1841, 288, 512, 1)
# tiny_sal_images (1841, 72, 128, 1)
# Time per video: 449.9032573699951 seconds, 7.498387706279755 minutes.
# 045_17_weather_forecast_static
# original_images (1842, 288, 512, 3)
# tiny_images (1842, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1842, 288, 512, 1)
# tiny_sal_images (1842, 72, 128, 1)
# Time per video: 450.1261303424835 seconds, 7.502102247873942 minutes.
# 045_18_bomb_trapped_static
# original_images (1787, 288, 512, 3)
# tiny_images (1787, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1787, 288, 512, 1)
# tiny_sal_images (1787, 72, 128, 1)
# Time per video: 430.82223534584045 seconds, 7.180370676517486 minutes.
# 045_20_car_fix_static
# original_images (1907, 288, 512, 3)
# tiny_images (1907, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1907, 288, 512, 1)
# tiny_sal_images (1907, 72, 128, 1)
# Time per video: 480.3537256717682 seconds, 8.00589550336202 minutes.
# 045_21_operation_room_static
# original_images (1900, 288, 512, 3)
# tiny_images (1900, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1900, 288, 512, 1)
# tiny_sal_images (1900, 72, 128, 1)
# Time per video: 476.06521582603455 seconds, 7.934420343240102 minutes.
# 045_23_dog_food_factory_motion
# original_images (1773, 288, 512, 3)
# tiny_images (1773, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1773, 288, 512, 1)
# tiny_sal_images (1773, 72, 128, 1)
# Time per video: 425.9803340435028 seconds, 7.09967231353124 minutes.
# 046_01_art_gallery_static
# original_images (1856, 288, 512, 3)
# tiny_images (1856, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1856, 288, 512, 1)
# tiny_sal_images (1856, 72, 128, 1)
# Time per video: 459.12369537353516 seconds, 7.652061669031779 minutes.
# 046_02_theatre_scene_static
# original_images (1858, 288, 512, 3)
# tiny_images (1858, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1858, 288, 512, 1)
# tiny_sal_images (1858, 72, 128, 1)
# Time per video: 457.294260263443 seconds, 7.621571079889933 minutes.
# 046_03_lions_static_cuts
# original_images (1859, 288, 512, 3)
# tiny_images (1859, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1859, 288, 512, 1)
# tiny_sal_images (1859, 72, 128, 1)
# Time per video: 461.572847366333 seconds, 7.692880872885386 minutes.
# 046_04_copenhagen_harbour_static_cuts
# original_images (1857, 288, 512, 3)
# tiny_images (1857, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1857, 288, 512, 1)
# tiny_sal_images (1857, 72, 128, 1)
# Time per video: 461.2144331932068 seconds, 7.686907295385996 minutes.
# 046_05_florida_yacht_motion
# original_images (1346, 288, 512, 3)
# tiny_images (1346, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1346, 288, 512, 1)
# tiny_sal_images (1346, 72, 128, 1)
# Time per video: 268.5711874961853 seconds, 4.476186541716258 minutes.
# 046_07_factory_robots_static
# original_images (1797, 288, 512, 3)
# tiny_images (1797, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1797, 288, 512, 1)
# tiny_sal_images (1797, 72, 128, 1)
# Time per video: 430.9171950817108 seconds, 7.181953330834706 minutes.
# 046_09_elephants_static
# No more frames
# original_images (1860, 288, 512, 3)
# tiny_images (1860, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1860, 288, 512, 1)
# tiny_sal_images (1860, 72, 128, 1)
# Time per video: 458.4887354373932 seconds, 7.641479003429413 minutes.
# 046_11_lohdi_garden_india_cuts
# original_images (1857, 288, 512, 3)
# tiny_images (1857, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1857, 288, 512, 1)
# tiny_sal_images (1857, 72, 128, 1)
# Time per video: 458.0193066596985 seconds, 7.633655194441477 minutes.
# 046_12_gym_workout_static
# original_images (1858, 288, 512, 3)
# tiny_images (1858, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1858, 288, 512, 1)
# tiny_sal_images (1858, 72, 128, 1)
# Time per video: 460.9569511413574 seconds, 7.682616126537323 minutes.
# 046_13_times_square_static
# original_images (1858, 288, 512, 3)
# tiny_images (1858, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1858, 288, 512, 1)
# tiny_sal_images (1858, 72, 128, 1)
# Time per video: 459.0293290615082 seconds, 7.65048889319102 minutes.
# 046_14_new_orleans_drive_motion
# original_images (1796, 288, 512, 3)
# tiny_images (1796, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1796, 288, 512, 1)
# tiny_sal_images (1796, 72, 128, 1)
# Time per video: 435.4294502735138 seconds, 7.257157595952352 minutes.
# 046_16_interview_static
# original_images (1858, 288, 512, 3)
# tiny_images (1858, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1858, 288, 512, 1)
# tiny_sal_images (1858, 72, 128, 1)
# Time per video: 457.32022166252136 seconds, 7.622003777821859 minutes.
# 046_17_weather_forecast_static
# original_images (1855, 288, 512, 3)
# tiny_images (1855, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1855, 288, 512, 1)
# tiny_sal_images (1855, 72, 128, 1)
# Time per video: 456.17536902427673 seconds, 7.602922896544139 minutes.
# 046_18_bomb_trapped_static
# original_images (1796, 288, 512, 3)
# tiny_images (1796, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1796, 288, 512, 1)
# tiny_sal_images (1796, 72, 128, 1)
# Time per video: 434.93771266937256 seconds, 7.248961957295736 minutes.
# 046_20_car_fix_static
# original_images (1917, 288, 512, 3)
# tiny_images (1917, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1917, 288, 512, 1)
# tiny_sal_images (1917, 72, 128, 1)
# Time per video: 481.3326690196991 seconds, 8.022211225827535 minutes.
# 046_21_operation_room_static
# original_images (1917, 288, 512, 3)
# tiny_images (1917, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1917, 288, 512, 1)
# tiny_sal_images (1917, 72, 128, 1)
# Time per video: 479.6605749130249 seconds, 7.994342986742655 minutes.
# 046_23_dog_food_factory_motion
# original_images (1795, 288, 512, 3)
# tiny_images (1795, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1795, 288, 512, 1)
# tiny_sal_images (1795, 72, 128, 1)
# Time per video: 434.6184093952179 seconds, 7.243640236059824 minutes.
# 047_01_art_gallery_static
# original_images (1847, 288, 512, 3)
# tiny_images (1847, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1847, 288, 512, 1)
# tiny_sal_images (1847, 72, 128, 1)
# Time per video: 455.37111258506775 seconds, 7.5895186305046085 minutes.
# 047_02_theatre_scene_static
# original_images (1858, 288, 512, 3)
# tiny_images (1858, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1858, 288, 512, 1)
# tiny_sal_images (1858, 72, 128, 1)
# Time per video: 457.3261568546295 seconds, 7.622102689743042 minutes.
# 047_03_lions_static_cuts
# original_images (1851, 288, 512, 3)
# tiny_images (1851, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1851, 288, 512, 1)
# tiny_sal_images (1851, 72, 128, 1)
# Time per video: 453.46975088119507 seconds, 7.557829260826111 minutes.
# 047_04_copenhagen_harbour_static_cuts
# original_images (1853, 288, 512, 3)
# tiny_images (1853, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1853, 288, 512, 1)
# tiny_sal_images (1853, 72, 128, 1)
# Time per video: 455.56405425071716 seconds, 7.5927343209584555 minutes.
# 047_05_florida_yacht_motion
# original_images (1348, 288, 512, 3)
# tiny_images (1348, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1348, 288, 512, 1)
# tiny_sal_images (1348, 72, 128, 1)
# Time per video: 268.32929277420044 seconds, 4.472154966990153 minutes.
# 047_07_factory_robots_static
# original_images (1794, 288, 512, 3)
# tiny_images (1794, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1794, 288, 512, 1)
# tiny_sal_images (1794, 72, 128, 1)
# Time per video: 427.67191648483276 seconds, 7.127865350246429 minutes.
# 047_08_madagascar_cuts
# original_images (1589, 288, 512, 3)
# tiny_images (1589, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1589, 288, 512, 1)
# tiny_sal_images (1589, 72, 128, 1)
# Time per video: 351.96113538742065 seconds, 5.866018998622894 minutes.
# 047_09_elephants_static
# original_images (1852, 288, 512, 3)
# tiny_images (1852, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1852, 288, 512, 1)
# tiny_sal_images (1852, 72, 128, 1)
# Time per video: 453.4147026538849 seconds, 7.556911786397298 minutes.
# 047_11_lohdi_garden_india_cuts
# original_images (1855, 288, 512, 3)
# tiny_images (1855, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1855, 288, 512, 1)
# tiny_sal_images (1855, 72, 128, 1)
# Time per video: 456.0843482017517 seconds, 7.601405878861745 minutes.
# 047_12_gym_workout_static
# No more frames
# original_images (1860, 288, 512, 3)
# tiny_images (1860, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1860, 288, 512, 1)
# tiny_sal_images (1860, 72, 128, 1)
# Time per video: 462.0854308605194 seconds, 7.701423927148183 minutes.
# 047_13_times_square_static
# original_images (1859, 288, 512, 3)
# tiny_images (1859, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1859, 288, 512, 1)
# tiny_sal_images (1859, 72, 128, 1)
# Time per video: 458.77140760421753 seconds, 7.646190214157104 minutes.
# 047_14_new_orleans_drive_motion
# No more frames
# original_images (1800, 288, 512, 3)
# tiny_images (1800, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1800, 288, 512, 1)
# tiny_sal_images (1800, 72, 128, 1)
# Time per video: 436.2884211540222 seconds, 7.271473769346873 minutes.
# 047_16_interview_static
# original_images (1857, 288, 512, 3)
# tiny_images (1857, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1857, 288, 512, 1)
# tiny_sal_images (1857, 72, 128, 1)
# Time per video: 455.58477425575256 seconds, 7.593079654375712 minutes.
# 047_17_weather_forecast_static
# original_images (1858, 288, 512, 3)
# tiny_images (1858, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1858, 288, 512, 1)
# tiny_sal_images (1858, 72, 128, 1)
# Time per video: 454.8550112247467 seconds, 7.580916933218638 minutes.
# 047_18_bomb_trapped_static
# original_images (1791, 288, 512, 3)
# tiny_images (1791, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1791, 288, 512, 1)
# tiny_sal_images (1791, 72, 128, 1)
# Time per video: 434.5163173675537 seconds, 7.241938706239065 minutes.
# 047_20_car_fix_static
# original_images (1913, 288, 512, 3)
# tiny_images (1913, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1913, 288, 512, 1)
# tiny_sal_images (1913, 72, 128, 1)
# Time per video: 479.52964639663696 seconds, 7.992160844802856 minutes.
# 047_21_operation_room_static
# No more frames
# original_images (1922, 288, 512, 3)
# tiny_images (1922, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1922, 288, 512, 1)
# tiny_sal_images (1922, 72, 128, 1)
# Time per video: 483.68316984176636 seconds, 8.061386239528655 minutes.
# 047_23_dog_food_factory_motion
# original_images (1801, 288, 512, 3)
# tiny_images (1801, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1801, 288, 512, 1)
# tiny_sal_images (1801, 72, 128, 1)
# Time per video: 436.80099654197693 seconds, 7.280016688505809 minutes.
# 048_01_art_gallery_static
# original_images (1855, 288, 512, 3)
# tiny_images (1855, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1855, 288, 512, 1)
# tiny_sal_images (1855, 72, 128, 1)
# Time per video: 460.7083704471588 seconds, 7.67847292025884 minutes.
# 048_02_theatre_scene_static
# original_images (1855, 288, 512, 3)
# tiny_images (1855, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1855, 288, 512, 1)
# tiny_sal_images (1855, 72, 128, 1)
# Time per video: 455.3181366920471 seconds, 7.58863567908605 minutes.
# 048_03_lions_static_cuts
# original_images (1842, 288, 512, 3)
# tiny_images (1842, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1842, 288, 512, 1)
# tiny_sal_images (1842, 72, 128, 1)
# Time per video: 449.16934037208557 seconds, 7.48615574836731 minutes.
# 048_04_copenhagen_harbour_static_cuts
# original_images (1852, 288, 512, 3)
# tiny_images (1852, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1852, 288, 512, 1)
# tiny_sal_images (1852, 72, 128, 1)
# Time per video: 454.82808017730713 seconds, 7.580468086401622 minutes.
# 048_05_florida_yacht_motion
# original_images (1347, 288, 512, 3)
# tiny_images (1347, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1347, 288, 512, 1)
# tiny_sal_images (1347, 72, 128, 1)
# Time per video: 268.968425989151 seconds, 4.482807183265686 minutes.
# 048_07_factory_robots_static
# original_images (1793, 288, 512, 3)
# tiny_images (1793, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1793, 288, 512, 1)
# tiny_sal_images (1793, 72, 128, 1)
# Time per video: 428.29132890701294 seconds, 7.138188898563385 minutes.
# 048_08_madagascar_cuts
# original_images (1579, 288, 512, 3)
# tiny_images (1579, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1579, 288, 512, 1)
# tiny_sal_images (1579, 72, 128, 1)
# Time per video: 347.656368970871 seconds, 5.794272891680399 minutes.
# 048_09_elephants_static
# original_images (1851, 288, 512, 3)
# tiny_images (1851, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1851, 288, 512, 1)
# tiny_sal_images (1851, 72, 128, 1)
# Time per video: 451.4423315525055 seconds, 7.524038938681285 minutes.
# 048_11_lohdi_garden_india_cuts
# original_images (1854, 288, 512, 3)
# tiny_images (1854, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1854, 288, 512, 1)
# tiny_sal_images (1854, 72, 128, 1)
# Time per video: 455.9378910064697 seconds, 7.598964933554331 minutes.
# 048_12_gym_workout_static
# original_images (1857, 288, 512, 3)
# tiny_images (1857, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1857, 288, 512, 1)
# tiny_sal_images (1857, 72, 128, 1)
# Time per video: 456.70441484451294 seconds, 7.611740318934123 minutes.
# 048_13_times_square_static
# original_images (1858, 288, 512, 3)
# tiny_images (1858, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1858, 288, 512, 1)
# tiny_sal_images (1858, 72, 128, 1)
# Time per video: 456.4791078567505 seconds, 7.607985210418701 minutes.
# 048_14_new_orleans_drive_motion
# original_images (1797, 288, 512, 3)
# tiny_images (1797, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1797, 288, 512, 1)
# tiny_sal_images (1797, 72, 128, 1)
# Time per video: 434.2985348701477 seconds, 7.238308986028035 minutes.
# 048_16_interview_static
# original_images (1852, 288, 512, 3)
# tiny_images (1852, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1852, 288, 512, 1)
# tiny_sal_images (1852, 72, 128, 1)
# Time per video: 453.61699962615967 seconds, 7.560283422470093 minutes.
# 048_17_weather_forecast_static
# original_images (1852, 288, 512, 3)
# tiny_images (1852, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1852, 288, 512, 1)
# tiny_sal_images (1852, 72, 128, 1)
# Time per video: 454.5001127719879 seconds, 7.575001962979635 minutes.
# 048_18_bomb_trapped_static
# original_images (1800, 288, 512, 3)
# tiny_images (1800, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1800, 288, 512, 1)
# tiny_sal_images (1800, 72, 128, 1)
# Time per video: 433.39090871810913 seconds, 7.223181895414988 minutes.
# 048_20_car_fix_static
# original_images (1915, 288, 512, 3)
# tiny_images (1915, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1915, 288, 512, 1)
# tiny_sal_images (1915, 72, 128, 1)
# Time per video: 480.42819690704346 seconds, 8.007136686642964 minutes.
# 048_21_operation_room_static
# original_images (1913, 288, 512, 3)
# tiny_images (1913, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1913, 288, 512, 1)
# tiny_sal_images (1913, 72, 128, 1)
# Time per video: 479.3846552371979 seconds, 7.989744341373443 minutes.
# 048_23_dog_food_factory_motion
# No more frames
# original_images (1801, 288, 512, 3)
# tiny_images (1801, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1801, 288, 512, 1)
# tiny_sal_images (1801, 72, 128, 1)
# Time per video: 447.0021162033081 seconds, 7.4500353535016375 minutes.
# 049_01_art_gallery_static
# original_images (1819, 288, 512, 3)
# tiny_images (1819, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1819, 288, 512, 1)
# tiny_sal_images (1819, 72, 128, 1)
# Time per video: 439.21558928489685 seconds, 7.32025990486145 minutes.
# 049_02_theatre_scene_static
# original_images (1826, 288, 512, 3)
# tiny_images (1826, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1826, 288, 512, 1)
# tiny_sal_images (1826, 72, 128, 1)
# Time per video: 445.1093955039978 seconds, 7.418490000565847 minutes.
# 049_03_lions_static_cuts
# original_images (1825, 288, 512, 3)
# tiny_images (1825, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1825, 288, 512, 1)
# tiny_sal_images (1825, 72, 128, 1)
# Time per video: 444.4657304286957 seconds, 7.407762253284455 minutes.
# 049_04_copenhagen_harbour_static_cuts
# original_images (1850, 288, 512, 3)
# tiny_images (1850, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1850, 288, 512, 1)
# tiny_sal_images (1850, 72, 128, 1)
# Time per video: 455.13674092292786 seconds, 7.585612424214681 minutes.
# 049_05_florida_yacht_motion
# original_images (1339, 288, 512, 3)
# tiny_images (1339, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1339, 288, 512, 1)
# tiny_sal_images (1339, 72, 128, 1)
# Time per video: 268.1938331127167 seconds, 4.4698973019917805 minutes.
# 049_07_factory_robots_static
# original_images (1774, 288, 512, 3)
# tiny_images (1774, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1774, 288, 512, 1)
# tiny_sal_images (1774, 72, 128, 1)
# Time per video: 419.925240278244 seconds, 6.998754088083903 minutes.
# 049_08_madagascar_cuts
# original_images (1572, 288, 512, 3)
# tiny_images (1572, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1572, 288, 512, 1)
# tiny_sal_images (1572, 72, 128, 1)
# Time per video: 346.47026777267456 seconds, 5.774504538377126 minutes.
# 049_09_elephants_static
# original_images (1826, 288, 512, 3)
# tiny_images (1826, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1826, 288, 512, 1)
# tiny_sal_images (1826, 72, 128, 1)
# Time per video: 441.04775404930115 seconds, 7.3507959842681885 minutes.
# 049_11_lohdi_garden_india_cuts
# original_images (1830, 288, 512, 3)
# tiny_images (1830, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1830, 288, 512, 1)
# tiny_sal_images (1830, 72, 128, 1)
# Time per video: 445.6531364917755 seconds, 7.427552350362142 minutes.
# 049_12_gym_workout_static
# original_images (1818, 288, 512, 3)
# tiny_images (1818, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1818, 288, 512, 1)
# tiny_sal_images (1818, 72, 128, 1)
# Time per video: 444.1787567138672 seconds, 7.402979358037313 minutes.
# 049_13_times_square_static
# original_images (1837, 288, 512, 3)
# tiny_images (1837, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1837, 288, 512, 1)
# tiny_sal_images (1837, 72, 128, 1)
# Time per video: 449.3250184059143 seconds, 7.488750390211741 minutes.
# 049_14_new_orleans_drive_motion
# original_images (1798, 288, 512, 3)
# tiny_images (1798, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1798, 288, 512, 1)
# tiny_sal_images (1798, 72, 128, 1)
# Time per video: 434.6261794567108 seconds, 7.2437697370847065 minutes.
# 049_17_weather_forecast_static
# original_images (1824, 288, 512, 3)
# tiny_images (1824, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1824, 288, 512, 1)
# tiny_sal_images (1824, 72, 128, 1)
# Time per video: 439.91705894470215 seconds, 7.331951065858205 minutes.
# 049_18_bomb_trapped_static
# original_images (1777, 288, 512, 3)
# tiny_images (1777, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1777, 288, 512, 1)
# tiny_sal_images (1777, 72, 128, 1)
# Time per video: 427.2200677394867 seconds, 7.120334545771281 minutes.
# 049_20_car_fix_static
# original_images (1889, 288, 512, 3)
# tiny_images (1889, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1889, 288, 512, 1)
# tiny_sal_images (1889, 72, 128, 1)
# Time per video: 467.9219398498535 seconds, 7.798699084917704 minutes.
# 049_21_operation_room_static
# original_images (1874, 288, 512, 3)
# tiny_images (1874, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1874, 288, 512, 1)
# tiny_sal_images (1874, 72, 128, 1)
# Time per video: 463.2874071598053 seconds, 7.721456877390543 minutes.
# 049_23_dog_food_factory_motion
# No more frames
# original_images (1801, 288, 512, 3)
# tiny_images (1801, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1801, 288, 512, 1)
# tiny_sal_images (1801, 72, 128, 1)
# Time per video: 435.9954471588135 seconds, 7.266590865453084 minutes.
# 050_01_art_gallery_static
# original_images (1829, 288, 512, 3)
# tiny_images (1829, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1829, 288, 512, 1)
# tiny_sal_images (1829, 72, 128, 1)
# Time per video: 448.22843766212463 seconds, 7.470474048455556 minutes.
# 050_02_theatre_scene_static
# original_images (1821, 288, 512, 3)
# tiny_images (1821, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1821, 288, 512, 1)
# tiny_sal_images (1821, 72, 128, 1)
# Time per video: 442.8581745624542 seconds, 7.380969651540121 minutes.
# 050_03_lions_static_cuts
# original_images (1817, 288, 512, 3)
# tiny_images (1817, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1817, 288, 512, 1)
# tiny_sal_images (1817, 72, 128, 1)
# Time per video: 439.8380298614502 seconds, 7.330633930365244 minutes.
# 050_04_copenhagen_harbour_static_cuts
# original_images (1829, 288, 512, 3)
# tiny_images (1829, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1829, 288, 512, 1)
# tiny_sal_images (1829, 72, 128, 1)
# Time per video: 444.817857503891 seconds, 7.413631037871043 minutes.
# 050_05_florida_yacht_motion
# original_images (1337, 288, 512, 3)
# tiny_images (1337, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1337, 288, 512, 1)
# tiny_sal_images (1337, 72, 128, 1)
# Time per video: 271.4967839717865 seconds, 4.524946475028992 minutes.
# 050_07_factory_robots_static
# original_images (1780, 288, 512, 3)
# tiny_images (1780, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1780, 288, 512, 1)
# tiny_sal_images (1780, 72, 128, 1)
# Time per video: 422.31190514564514 seconds, 7.038531835873922 minutes.
# 050_08_madagascar_cuts
# original_images (1560, 288, 512, 3)
# tiny_images (1560, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1560, 288, 512, 1)
# tiny_sal_images (1560, 72, 128, 1)
# Time per video: 339.9876878261566 seconds, 5.666461547215779 minutes.
# 050_09_elephants_static
# original_images (1826, 288, 512, 3)
# tiny_images (1826, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1826, 288, 512, 1)
# tiny_sal_images (1826, 72, 128, 1)
# Time per video: 444.70281291007996 seconds, 7.411713631947835 minutes.
# 050_11_lohdi_garden_india_cuts
# original_images (1829, 288, 512, 3)
# tiny_images (1829, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1829, 288, 512, 1)
# tiny_sal_images (1829, 72, 128, 1)
# Time per video: 445.5084264278412 seconds, 7.425140519936879 minutes.
# 050_12_gym_workout_static
# original_images (1819, 288, 512, 3)
# tiny_images (1819, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1819, 288, 512, 1)
# tiny_sal_images (1819, 72, 128, 1)
# Time per video: 441.23196625709534 seconds, 7.353866183757782 minutes.
# 050_13_times_square_static
# original_images (1816, 288, 512, 3)
# tiny_images (1816, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1816, 288, 512, 1)
# tiny_sal_images (1816, 72, 128, 1)
# Time per video: 440.9490888118744 seconds, 7.349151567618052 minutes.
# 050_14_new_orleans_drive_motion
# original_images (1778, 288, 512, 3)
# tiny_images (1778, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1778, 288, 512, 1)
# tiny_sal_images (1778, 72, 128, 1)
# Time per video: 426.64582777023315 seconds, 7.110763875643412 minutes.
# 050_16_interview_static
# original_images (1840, 288, 512, 3)
# tiny_images (1840, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1840, 288, 512, 1)
# tiny_sal_images (1840, 72, 128, 1)
# Time per video: 451.2726068496704 seconds, 7.52121020158132 minutes.
# 050_17_weather_forecast_static
# original_images (1840, 288, 512, 3)
# tiny_images (1840, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1840, 288, 512, 1)
# tiny_sal_images (1840, 72, 128, 1)
# Time per video: 451.0447599887848 seconds, 7.517412745952607 minutes.
# 050_18_bomb_trapped_static
# original_images (1782, 288, 512, 3)
# tiny_images (1782, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1782, 288, 512, 1)
# tiny_sal_images (1782, 72, 128, 1)
# Time per video: 436.24409890174866 seconds, 7.2707350571950276 minutes.
# 050_20_car_fix_static
# original_images (1880, 288, 512, 3)
# tiny_images (1880, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1880, 288, 512, 1)
# tiny_sal_images (1880, 72, 128, 1)
# Time per video: 465.85392212867737 seconds, 7.76423210700353 minutes.
# 050_21_operation_room_static
# original_images (1875, 288, 512, 3)
# tiny_images (1875, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1875, 288, 512, 1)
# tiny_sal_images (1875, 72, 128, 1)
# Time per video: 466.7273118495941 seconds, 7.778788610299428 minutes.
# 050_23_dog_food_factory_motion
# original_images (1796, 288, 512, 3)
# tiny_images (1796, 72, 128, 3)
# Starting generation of saliency maps
# sal_images (1796, 288, 512, 1)
# tiny_sal_images (1796, 72, 128, 1)
# Time per video: 438.90444111824036 seconds, 7.315074098110199 minutes.
